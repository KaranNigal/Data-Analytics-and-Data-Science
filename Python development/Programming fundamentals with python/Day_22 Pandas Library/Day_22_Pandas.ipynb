# %%
# importing pandas library as alias name pd
import pandas as pd
# !pip install pandas

# %%
# What is pandas?

# library for data analysis and manipulation
# Works with CSV, Excel, SQL,weblink etc.

# %%
# series in pandas
a= pd.Series([1,2,3,4,5])
print(a)
# by default stores integers as 8 bytes ie. long integers
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# series with custom labels / index

# %%
c= pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
print(c)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
# DataFrames - Creation

# 👉 From dictionary

# %%
data = {
    'id': [101, 102, 103, 104, 105],
    'name': ['Arun', 'Nilesh', 'Ajit', 'Prashant', 'Priya'],
    'city': ['Mumbai', 'Pune', 'Surat', 'Gujarat', 'Satara']
}
df1= pd.DataFrame(data)
df1
# Out:
#     id      name     city
# 0  101      Arun   Mumbai
# 1  102    Nilesh     Pune
# 2  103      Ajit    Surat
# 3  104  Prashant  Gujarat
# 4  105     Priya   Satara

# %%
# From list of records to data frame

# %%
emp = [(101, 'HR', 'Pune'), (102, 'IT', 'Pune'), (105, 'CS', 'Pune')]
df2= pd.DataFrame(emp, columns=["id","dept","city"])
df2
# Out:
#     id dept  city
# 0  101   HR  Pune
# 1  102   IT  Pune
# 2  105   CS  Pune

# %%
# to convert a csv into pandas data frame

# %%
df3= pd.read_csv('/Superstore.csv')
df3.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2018-152156  08-11-2018  11-11-2018    Second Class    CG-12520
# 1       2  CA-2018-152156  08-11-2018  11-11-2018    Second Class    CG-12520
# 2       3  CA-2018-138688  12-06-2018  16-06-2018    Second Class    DV-13045
# 3       4  US-2017-108966  11-10-2017  18-10-2017  Standard Class    SO-20335
# 4       5  US-2017-108966  11-10-2017  18-10-2017  Standard Class    SO-20335
#
#      Customer Name    Segment Country/Region             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df3.shape
# Out:
# (9994, 21)

# %%
df3.size
# Out:
# 209874

# %%
# head shows first 5 columns or customized rows
df3.head(7)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2018-152156  08-11-2018  11-11-2018    Second Class    CG-12520
# 1       2  CA-2018-152156  08-11-2018  11-11-2018    Second Class    CG-12520
# 2       3  CA-2018-138688  12-06-2018  16-06-2018    Second Class    DV-13045
# 3       4  US-2017-108966  11-10-2017  18-10-2017  Standard Class    SO-20335
# 4       5  US-2017-108966  11-10-2017  18-10-2017  Standard Class    SO-20335
# 5       6  CA-2016-115812  09-06-2016  14-06-2016  Standard Class    BH-11710
# 6       7  CA-2016-115812  09-06-2016  14-06-2016  Standard Class    BH-11710
#
#      Customer Name    Segment Country/Region             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# ...

# %%
# df.sum()

# this code shows us the sum of data in each column

# %%
from numpy._core import numerictypes
df3.sum(numeric_only= True)  # here we will add only the numeric columns and ignore non numeric ones
# Out:
# Row ID         4.994502e+07
# Postal Code    5.515132e+08
# Sales          2.297201e+06
# Quantity       3.787300e+04
# Discount       1.561090e+03
# Profit         2.863970e+05
# dtype: float64

# %%
# to show mean or avg of all the numeric columns
df3.mean(numeric_only= True)
# Out:
# Row ID          4997.500000
# Postal Code    55245.233297
# Sales            229.858001
# Quantity           3.789574
# Discount           0.156203
# Profit            28.656896
# dtype: float64

# %%
# to check all the column names of our data set
df3.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
# to check out a specific column
df3['Sales']
# Out:
# 0       261.9600
# 1       731.9400
# 2        14.6200
# 3       957.5775
# 4        22.3680
#           ...
# 9989     25.2480
# 9990     91.9600
# 9991    258.5760
# 9992     29.6000
# 9993    243.1600
# Name: Sales, Length: 9994, dtype: float64

# %%
# to take out a column and print its total sum
df3['Sales'].sum()
# Out:
# np.float64(2297200.8603000003)

# %%
df3['Profit'].sum()
# Out:
# np.float64(286397.0217)

# %%
df3['Quantity'].sum()
# Out:
# np.int64(37873)

# %%
# df.describe()

# count: Number of non-missing values

# mean: Arithmetic average

# std: Standard deviation

# min: Minimum value

# 25%: 25th percentile (Q1)

# 50%: Median (Q2)

# 75%: 75th percentile (Q3)

# max: Maximum value

# %%
# converting the int columns to string that are not neccesary for numerical calculations
df3['Row ID']= df3['Row ID'].astype(str)
df3['Postal Code']= df3['Postal Code'].astype(str)

# %%
# df.describe()

# count: Number of non-missing values

# mean: Arithmetic average

# std: Standard deviation

# min: Minimum value

# 25%: 25th percentile (Q1)

# 50%: Median (Q2)

# 75%: 75th percentile (Q3)

# max: Maximum value

# %%
df3.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %%
# # df.describe(include=['object'])

# count: Number of non-missing values

# unique: Number of unique categories

# top: Most frequent category

# freq: Frequency of the most common category

# %%
df3.describe(include=['object'])
# Out:
#        Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# count    9994            9994        9994        9994            9994
# unique   9994            5009        1236        1334               4
# top      9994  CA-2019-100111  05-09-2018  16-12-2017  Standard Class
# freq        1              14          38          35            5968
#
#        Customer ID  Customer Name   Segment Country/Region           City  \
# count         9994           9994      9994           9994           9994
# unique         793            793         3              1            531
# top       WB-21850  William Brown  Consumer  United States  New York City
# freq            37             37      5191           9994            915
#
#              State Postal Code Region       Product ID         Category  \
# count         9994        9994   9994             9994             9994
# unique          49         631      4             1862                3
# ...

# %%
len(df3) # gives total no of rows
# Out:
# 9994

# %%
df3.columns.size
# Out:
# 21

# %%
# display records 101 to 105
df3[101:106] # 106 excluded
# Out:
#     Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 101    102  CA-2018-158568  29-08-2018  02-09-2018  Standard Class
# 102    103  CA-2018-129903  01-12-2018  04-12-2018    Second Class
# 103    104  US-2017-156867  13-11-2017  17-11-2017  Standard Class
# 104    105  US-2017-156867  13-11-2017  17-11-2017  Standard Class
# 105    106  US-2017-156867  13-11-2017  17-11-2017  Standard Class
#
#     Customer ID  Customer Name      Segment Country/Region       City  ...  \
# 101    RB-19465   Rick Bensley  Home Office  United States    Chicago  ...
# 102    GZ-14470  Gary Zandusky     Consumer  United States  Rochester  ...
# 103    LC-16870  Lena Cacioppo     Consumer  United States     Aurora  ...
# 104    LC-16870  Lena Cacioppo     Consumer  United States     Aurora  ...
# 105    LC-16870  Lena Cacioppo     Consumer  United States     Aurora  ...
#
#     Postal Code   Region       Product ID         Category Sub-Category  \
# ...

# %%
# for specific rows and colums
df3[['Row ID', 'Order ID', 'Sales', 'Profit', 'Region','Customer ID']][3:8]
# Out:
#   Row ID        Order ID     Sales    Profit Region Customer ID
# 3      4  US-2017-108966  957.5775 -383.0310  South    SO-20335
# 4      5  US-2017-108966   22.3680    2.5164  South    SO-20335
# 5      6  CA-2016-115812   48.8600   14.1694   West    BH-11710
# 6      7  CA-2016-115812    7.2800    1.9656   West    BH-11710
# 7      8  CA-2016-115812  907.1520   90.7152   West    BH-11710

# %%
# df.iloc[[n],[n]]

# this code brings the data in nth row and nth column in dataFrame

# %%
df3.iloc[4,5]
# Out:
# 'SO-20335'

# %%
df3.iloc[89,7]
# Out:
# 'Corporate'

# %%
# loc → label-based indexing (uses row/column labels, not integer positions).

# %%
df3.loc[45,'Category']
# Out:
# 'Office Supplies'

# %%
df3.loc[69,'City']
# Out:
# 'Springfield'

# %%
# to return multiple columns and rows using loc
df3.loc[3:9,['City','Category']]
# Out:
#               City         Category
# 3  Fort Lauderdale        Furniture
# 4  Fort Lauderdale  Office Supplies
# 5      Los Angeles        Furniture
# 6      Los Angeles  Office Supplies
# 7      Los Angeles       Technology
# 8      Los Angeles  Office Supplies
# 9      Los Angeles  Office Supplies

# %%
df3.loc[45:59:3,['Region','Sales']] # we can  use steps as well
# Out:
#      Region    Sales
# 45  Central    17.46
# 48     East    21.80
# 51  Central     6.16
# 54     East  1029.95
# 57     East   319.41

# %%
# df['columnName'][n]

# this code we can select and return any value of the column we want

# %%
df3['Segment'][5000]
# Out:
# 'Home Office'

# %%
# df['ColumnName'].nunique()

# gives number of unique values in column

# %%
df3['State'].nunique() #total 49 states in our dataset
# Out:
# 49

# %%
# df["column name"].unique()

# this code count all of the data in the column we have specified,but does not count null/none values

# %%
df3['Product Name'].unique()
# Out:
# array(['Bush Somerset Collection Bookcase',
#        'Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back',
#        'Self-Adhesive Address Labels for Typewriters by Universal', ...,
#        'Eureka Hand Vacuum, Bagless', 'LG G2',
#        'Eldon Jumbo ProFile Portable File Boxes Graphite/Black'],
#       dtype=object)

# %%
df3['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)
