# %%
#String data type
s= "amit"
type(s)
# Out:
# str

# %%
#string can be declared using signle quotes as well
s='karan'

# %%
#string when is multiple lined , use triple double quotes
s="""Maverick 
is 
the 
best"""
print(s)
# Out:
# Maverick
# is
# the
# best

# %%
# #types of operator 
# 1.arithmatic operators
# +,-,*,/
# // -- floor division
# ** --power
# % --modulo
a=70
b=5
print(a+b, a-b, a*b, a/b, a**b, a//b, a%b)
# Out:
# 75 65 350 14.0 1680700000 14 0

# %%
#demo of ceil and floor division
import math
print(math.ceil(10/3))
print(10//3)
# Out:
# 4
# 3

# %%
#demo of the modulo operator,it returns the remainder 
print(100%3)
# Out:
# 1

# %%
#demo of power operator
9**3
# Out:
# 729

# %%
#arithmatic operators(only +,*) can be used with strings as well
a="Karan"
b=" Nigal"
print(a+b) #concatenation
print(a*2)
# Out:
# Karan Nigal
# KaranKaran

# %%
# relational operator or comparison operator
# >
# <
# >=
# <=
# ==
# !=

# %%
a=90
b=110
print(a<b)
print(a<=b)
print(a>b)
print(a>=b)
print(a==b)
print(a!=b)
# Out:
# True
# True
# False
# False
# False
# True

# %%
#demo of equal to(==) and not equal to (!=) operator
print(10%2==1)
print(10%2!=1)
# Out:
# False
# True

# %%
#two strings can be comapred on the basis of their ASCII values
"a">"A"
# Out:
# True

# %%
print("a"=="A")
# Out:
# False

# %%
#to find ASCII values from string
ord("a")
# Out:
# 97

# %%
#to find character from ASCII value
chr(97)
# Out:
# 'a'

# %%
#this will compare length
print("karan" < "maverick")
print("karan"> "shran")
# Out:
# True
# False

# %%
"Karan" == "Karan"
# Out:
# True

# %%
#logical operators
# and , or , not
# operands are boolean data type

# %%
print(True and True)
print(True and False)
print(False and False)
# Out:
# True
# False
# False

# %%
print(True or True)
print(True or False)
print(False or False)
# Out:
# True
# True
# False

# %%
# logical operator on non boolean operands
# x and y (x,y are non boolean)
# -- if x is zero or empty seq then answer is x
# -- if x is non-zero or non-empty seq then answer is y

# %%
0 and 45
# Out:
# 0

# %%
1 and 45
# Out:
# 45

# %%
"" and  89
# Out:
# ''

# %%
[] and 45
# Out:
# []

# %%
[10,20,30] and 65
# Out:
# 65

# %%
0 and 0
# Out:
# 0

# %%
1 and 0
# Out:
# 0

# %%
"Karan" and "Maverick"
# Out:
# 'Maverick'

# %%
"" and "done"
# Out:
# ''

# %%
# logical operator on non boolean operands
# x or y (x,y are non boolean)
# -- if x is zero or empty seq then answer is y
# -- if x is non-zero or non-empty seq then answer is x

# %%
0 or 25
# Out:
# 25

# %%
77 or 56
# Out:
# 77

# %%
"Karan" or "Maverick"
# Out:
# 'Karan'

# %%
[] or 88
# Out:
# 88

# %%
[] or [] or "ok"
# Out:
# 'ok'

# %%
[] and [] and "ok" or "ok"
# Out:
# 'ok'

# %%
# not operator negates the boolean value
print(not 99)
print(not 0)
print(not "Maverick")
print(not "")
# Out:
# False
# True
# False
# True

# %%
# Assignment operator 
name= "Karan"
score= "100"

# %%
#assignment operator can be combined with arithmaic operator to shorten equation
a=10
a+=30 # a= a+30
print(a)
# Out:
# 40

# %%
# Membership operator (use of in)
k=[1,2,3,4,5,"sham"]
print("sham" in k)
print("aditi" in k)
# Out:
# True
# False

# %%
# membership opertor with string
s="aditi"
"k" in s
# Out:
# False

# %%
# membership operator (use of not in)
l="lion"
print("t" not in l)
print("l" not in l)
# Out:
# True
# False

# %%
# identity operator
# -- is
# -- is not
# compares adress of the operands

# %%
a=10
b=10
print(id(a))
print(id(b))
print(a is b)
# Out:
# 140726329976008
# 140726329976008
# True

# %%
a=260
b=260
print(id(a))
print(id(b))
print(a is b)
# Out:
# 2053035858992
# 2053035860464
# False

# %%
s="Karan"
k="Karan"
s is k
# Out:
# True

# %%
s="Karan"
k="karan"
s is k
# Out:
# False

# %%
s="Karan"
k="karan"
s is not k
# Out:
# True

# %%
#try with list
a=[1,2,3,4,5]
b=[1,2,3,4,5]
#stored at different memory location
print(id(a))
print(id(b))
a in b
# Out:
# 2053036553472
# 2053036540928
# False

# %%
a=[1,2,3,4,5]
b=[1,2,3,4,5]
a==b
# Out:
# True
