# %%
#trying variable name for rules understanding 
#small case
name= "maverick"
print(name)
# Out:
# maverick

# %%
#starting capital
Name= "maverick"
print(name)
# Out:
# maverick

# %%
#all capital
NAME= "maverick"
print(NAME)
# Out:
# maverick

# %%
#try adding number
name1= "karan"
name2= "rishi"
print(name1, name2)
# Out:
# karan rishi

# %%
#starts with number 
1name= "Om"
#indentifier never starts with digit
# Out:
#   Cell In[7], line 2
#     1name= "Om"
#     ^
# SyntaxError: invalid decimal literal

# %%
#python is case sensitive language 
# hence identifier is case sensitive
a=55
print(A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 #python is case sensitive language
#       2 # hence identifier is case sensitive
#       3 a=55
# ----> 4 print(A)
#       5 print(a)
#
# NameError: name 'A' is not defined

# %%
#lets see the reserved keywords in python
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
#keywords can be used as variable
#lets try with keyword as variable
and= "hi"
# Out:
#   Cell In[11], line 3
#     and= "hi"
#     ^
# SyntaxError: invalid syntax

# %%
True=65
# Out:
#   Cell In[13], line 1
#     True=65
#     ^
# SyntaxError: cannot assign to True

# %%
#if there is function defined in python and we use it as a varibale , the funcion becomes uncallable and return error
print=65
del print # deleted variable to make print callable
print("hi")
# Out:
# hi

# %%
#special characters cant be used in naming identifiers
kri$na= "dollar sign"
# Out:
#   Cell In[16], line 2
#     kri$na= "dollar sign"
#        ^
# SyntaxError: invalid syntax

# %%
#undersocre can be used anywhere while naming 
_a=100
print(_a)
# Out:
# 100

# %%
#cant start values of variable with zero unless it is a octal number
a=02
# Out:
#   Cell In[19], line 2
#     a=02
#       ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
#no spaces can be used in naming
#use underscore ie. snake-case
name_of_student= "Jacky"

# %%
#The variable naming should follow snake case convention
#all things lower case and words separated by underscore
student_name= "Karan"
total_marks= 450
account_balance= 500
print(student_name)
# Out:
# Karan

# %%
# data types in python
# fundamental variable
#int, float, bool, string

# %%
#int data type
a=10
print(a)
type(a)
print(id(a))
# Out:
# 10
# 140727285163208

# %%
#fundamental data types are immutable hence making changes to existing variable changes the address 
a=11
print(id(a))
# Out:
# 140727285163240

# %%
account_balance= 50000
withdraw_amount= 2000
remaining_amount= account_balance - withdraw_amount
print(remaining_amount)
# Out:
# 48000

# %%
#if a value is stored in memory space, multiple variable access the same adress
a=10
id(a)
# Out:
# 140727285163208

# %%
b=10
id(b)
#this happens only up till 258
# Out:
# 140727285163208

# %%
#float data type
a=18.06
b=3.1456378
print(type(a))
print(type(b))
print(a+b)
print(id(a))
# Out:
# <class 'float'>
# <class 'float'>
# 21.205637799999998
# 1595077736656

# %%
#use of exponential 
a=7.2e14 #e can go till 15 only
print(a)
# Out:
# 720000000000000.0

# %%
#arithmatic operation with float and int data type
a=10.5
b=5
print(a+b)
print(a-b)
print(a*b)
print(a%b)
print(a/b)
# Out:
# 15.5
# 5.5
# 52.5
# 0.5
# 2.1

# %%
#boolean data type
a=True
type(a)
# Out:
# bool

# %%
print(False)
type(False)
# Out:
# False
# bool

# %%
10>20
# Out:
# False

# %%
10<20
# Out:
# True

# %%
print(True+True)
print(True+False)
print(False+False)
# Out:
# 2
# 1
# 0

# %%
print(True*True)
print(True*False)
print(False*False)
# Out:
# 1
# 0
# 0

# %%
#string data type
#string can be in single or double quote
a="karan"
print(a)
# Out:
# karan

# %%
a='karan'
print(a)
id(a)
# Out:
# karan
# 1595079271376

# %%
# strings are also immutable
a='varun'
id(a)
# Out:
# 1595081207088
