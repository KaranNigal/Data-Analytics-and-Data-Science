# %%
# Demo of print
print("Hello world! I am Maverick")
# Out:
# Hello world! I am Maverick

# %%
# Demo of print
print("Karan was here")
# Out:
# Karan was here

# %%
# Demo of print
print(70-50)
print(10-50)
print(40+10)
print(25*-4)
print(25*4)
print(75/-5)
print(75/5)
# Out:
# 20
# -40
# 50
# -100
# 100
# -15.0
# 15.0

# %%
# Demo of dynamically typed
a=10
print(type(a))
# Out:
# <class 'int'>

# %%
# Demo of dynamically typed
b="Maverick"
print(type(b))
# Out:
# <class 'str'>

# %%
# Demo of interpreted language (line by line translation)
print("Hello Maverick")
print(10/0)
print("Namaste")
# Out:
# Hello Maverick
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_752/801874716.py in <cell line: 0>()
#       1 # Demo of interpreted language (line by line translation)
#       2 print("Hello Maverick")
# ----> 3 print(10/0)
#       4 print("Namaste")
#
# ZeroDivisionError: division by zero

# %%
#keywords in python total 35 ie simple language
import keyword
print(keyword.kwlist)
print(len(keyword.kwlist))
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 35
